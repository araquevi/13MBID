# %% [markdown]
# ## Máster en Big Data y Data Science
#
# ### Metodologías de gestión y diseño de proyectos de big data
#
# #### AP1 - Exploración de los datos
#
# ---
#
# En esta libreta se realiza un EDA -básico- de los datos del escenario.
#
# ---

# %% [markdown]
# ##### Importación de librerías

# %%
import pandas as pd
# from ydata_profiling import ProfileReport
import dtale as dt
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ----
#
# ##### Lectura de los datasets

# %%
df_creditos = pd.read_csv("../../data/raw/datos_creditos.csv", sep=";")
df_creditos.head(1)
# Out:
#     id_cliente  edad  importe_solicitado  duracion_credito  \
# 0  713061558.0    22               35000                 3
#
#    antiguedad_empleado situacion_vivienda  ingresos objetivo_credito  \
# 0                123.0           ALQUILER     59000         PERSONAL
#
#    pct_ingreso  tasa_interes  estado_credito falta_pago
# 0         0.59         16.02               1          Y

# %%
df_tarjetas = pd.read_csv("../../data/raw/datos_tarjetas.csv", sep=";")
df_tarjetas.head(1)
# Out:
#     id_cliente  antiguedad_cliente estado_civil estado_cliente  \
# 0  713061558.0                36.0       CASADO         ACTIVO
#
#    gastos_ult_12m genero  limite_credito_tc         nivel_educativo  \
# 0          1088.0      M             4010.0  UNIVERSITARIO_COMPLETO
#
#   nivel_tarjeta  operaciones_ult_12m  personas_a_cargo
# 0          Blue                 24.0               2.0

# %% [markdown]
# ----
#
# ##### Descripción de los datasets

# %%
def reporte_descripcion_dataset(df):
    columnas = df.columns
    print("Columnas del dataset:\n")
    for col in columnas:
        print(col)
    print(f"\nCantidad de filas: {df.shape[0]}")

# %%
print("Descripción del dataset 'datos_creditos'")
reporte_descripcion_dataset(df_creditos)
# Out:
# Descripción del dataset 'datos_creditos'
# Columnas del dataset:
#
# id_cliente
# edad
# importe_solicitado
# duracion_credito
# antiguedad_empleado
# situacion_vivienda
# ingresos
# objetivo_credito
# pct_ingreso
# tasa_interes
# estado_credito
# falta_pago
#
# Cantidad de filas: 10127

# %%
print("Descripción del dataset 'datos_tarjetas'")
reporte_descripcion_dataset(df_tarjetas)
# Out:
# Descripción del dataset 'datos_tarjetas'
# Columnas del dataset:
#
# id_cliente
# antiguedad_cliente
# estado_civil
# estado_cliente
# gastos_ult_12m
# genero
# limite_credito_tc
# nivel_educativo
# nivel_tarjeta
# operaciones_ult_12m
# personas_a_cargo
#
# Cantidad de filas: 10127

# %% [markdown]
# ----
#
# ##### Obtención de metadatos

# %%
# Se usa la librería dtale para poder obtener una vista interactiva de los datos

# Dataset: datos_creditos

creditos = dt.show(df_creditos)
creditos.open_browser()
# Out:
# 2024-04-20 17:50:13,139 - ERROR    - Exception occurred while processing request: agg function failed [how->mean,dtype->object]
# Traceback (most recent call last):
#   File "c:\Users\victo\Desktop\MasterTrabajos\13MBID\13MBID\.venv\lib\site-packages\pandas\core\groupby\groupby.py", line 1942, in _agg_py_fallback
#     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#   File "c:\Users\victo\Desktop\MasterTrabajos\13MBID\13MBID\.venv\lib\site-packages\pandas\core\groupby\ops.py", line 864, in agg_series
#     result = self._aggregate_series_pure_python(obj, func)
#   File "c:\Users\victo\Desktop\MasterTrabajos\13MBID\13MBID\.venv\lib\site-packages\pandas\core\groupby\ops.py", line 885, in _aggregate_series_pure_python
#     res = func(group)
#   File "c:\Users\victo\Desktop\MasterTrabajos\13MBID\13MBID\.venv\lib\site-packages\pandas\core\groupby\groupby.py", line 2454, in <lambda>
#     alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#   File "c:\Users\victo\Desktop\MasterTrabajos\13MBID\13MBID\.venv\lib\site-packages\pandas\core\series.py", line 6540, in mean
#     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   File "c:\Users\victo\Desktop\MasterTrabajos\13MBID\13MBID\.venv\lib\site-packages\pandas\core\generic.py", line 12417, in mean
#     return self._stat_function(
#   File "c:\Users\victo\Desktop\MasterTrabajos\13MBID\13MBID\.venv\lib\site-packages\pandas\core\generic.py", line 12374, in _stat_function
#     return self._reduce(
#   File "c:\Users\victo\Desktop\MasterTrabajos\13MBID\13MBID\.venv\lib\site-packages\pandas\core\series.py", line 6448, in _reduce
#     return op(delegate, skipna=skipna, **kwds)
#   File "c:\Users\victo\Desktop\MasterTrabajos\13MBID\13MBID\.venv\lib\site-packages\pandas\core\nanops.py", line 147, in f
#     result = alt(values, axis=axis, skipna=skipna, **kwds)
#   File "c:\Users\victo\Desktop\MasterTrabajos\13MBID\13MBID\.venv\lib\site-packages\pandas\core\nanops.py", line 404, in new_func
#     result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#   File "c:\Users\victo\Desktop\MasterTrabajos\13MBID\13MBID\.venv\lib\site-packages\pandas\core\nanops.py", line 720, in nanmean
#     the_sum = _ensure_numeric(the_sum)
#   File "c:\Users\victo\Desktop\MasterTrabajos\13MBID\13MBID\.venv\lib\site-packages\pandas\core\nanops.py", line 1701, in _ensure_numeric
#     raise TypeError(f"Could not convert string '{x}' to numeric")
# TypeError: Could not convert string '...' to numeric
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\victo\Desktop\MasterTrabajos\13MBID\13MBID\.venv\lib\site-packages\dtale\views.py", line 119, in _handle_exceptions
#     return func(*args, **kwargs)
#   File "c:\Users\victo\Desktop\MasterTrabajos\13MBID\13MBID\.venv\lib\site-packages\dtale\views.py", line 3135, in get_column_analysis
#     return jsonify(**analysis.build())
#   File "c:\Users\victo\Desktop\MasterTrabajos\13MBID\13MBID\.venv\lib\site-packages\dtale\column_analysis.py", line 141, in build
#     return_data, code = self.analysis.build(self)
#   File "c:\Users\victo\Desktop\MasterTrabajos\13MBID\13MBID\.venv\lib\site-packages\dtale\column_analysis.py", line 326, in build
#     ].agg(self.aggs)
#   File "c:\Users\victo\Desktop\MasterTrabajos\13MBID\13MBID\.venv\lib\site-packages\pandas\core\groupby\generic.py", line 1432, in aggregate
#     result = op.agg()
#   File "c:\Users\victo\Desktop\MasterTrabajos\13MBID\13MBID\.venv\lib\site-packages\pandas\core\apply.py", line 193, in agg
#     return self.agg_list_like()
#   File "c:\Users\victo\Desktop\MasterTrabajos\13MBID\13MBID\.venv\lib\site-packages\pandas\core\apply.py", line 326, in agg_list_like
#     return self.agg_or_apply_list_like(op_name="agg")
#   File "c:\Users\victo\Desktop\MasterTrabajos\13MBID\13MBID\.venv\lib\site-packages\pandas\core\apply.py", line 1571, in agg_or_apply_list_like
#     keys, results = self.compute_list_like(op_name, selected_obj, kwargs)
#   File "c:\Users\victo\Desktop\MasterTrabajos\13MBID\13MBID\.venv\lib\site-packages\pandas\core\apply.py", line 385, in compute_list_like
#     new_res = getattr(colg, op_name)(func, *args, **kwargs)
#   File "c:\Users\victo\Desktop\MasterTrabajos\13MBID\13MBID\.venv\lib\site-packages\pandas\core\groupby\generic.py", line 257, in aggregate
#     ret = self._aggregate_multiple_funcs(func, *args, **kwargs)
#   File "c:\Users\victo\Desktop\MasterTrabajos\13MBID\13MBID\.venv\lib\site-packages\pandas\core\groupby\generic.py", line 362, in _aggregate_multiple_funcs
#     results[key] = self.aggregate(func, *args, **kwargs)
#   File "c:\Users\victo\Desktop\MasterTrabajos\13MBID\13MBID\.venv\lib\site-packages\pandas\core\groupby\generic.py", line 249, in aggregate
#     return getattr(self, func)(*args, **kwargs)
#   File "c:\Users\victo\Desktop\MasterTrabajos\13MBID\13MBID\.venv\lib\site-packages\pandas\core\groupby\groupby.py", line 2452, in mean
#     result = self._cython_agg_general(
#   File "c:\Users\victo\Desktop\MasterTrabajos\13MBID\13MBID\.venv\lib\site-packages\pandas\core\groupby\groupby.py", line 1998, in _cython_agg_general
#     new_mgr = data.grouped_reduce(array_func)
#   File "c:\Users\victo\Desktop\MasterTrabajos\13MBID\13MBID\.venv\lib\site-packages\pandas\core\internals\base.py", line 367, in grouped_reduce
#     res = func(arr)
#   File "c:\Users\victo\Desktop\MasterTrabajos\13MBID\13MBID\.venv\lib\site-packages\pandas\core\groupby\groupby.py", line 1995, in array_func
#     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#   File "c:\Users\victo\Desktop\MasterTrabajos\13MBID\13MBID\.venv\lib\site-packages\pandas\core\groupby\groupby.py", line 1946, in _agg_py_fallback
#     raise type(err)(msg) from err
# TypeError: agg function failed [how->mean,dtype->object]
# 2024-04-20 17:54:55,048 - ERROR    - Exception occurred while processing request: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# Traceback (most recent call last):
#   File "c:\Users\victo\Desktop\MasterTrabajos\13MBID\13MBID\.venv\lib\site-packages\dtale\views.py", line 119, in _handle_exceptions
#     return func(*args, **kwargs)
#   File "c:\Users\victo\Desktop\MasterTrabajos\13MBID\13MBID\.venv\lib\site-packages\dtale\views.py", line 3135, in get_column_analysis
#     return jsonify(**analysis.build())
#   File "c:\Users\victo\Desktop\MasterTrabajos\13MBID\13MBID\.venv\lib\site-packages\dtale\column_analysis.py", line 141, in build
#     return_data, code = self.analysis.build(self)
#   File "c:\Users\victo\Desktop\MasterTrabajos\13MBID\13MBID\.venv\lib\site-packages\dtale\column_analysis.py", line 185, in build
#     return_data, hist_labels = self.build_histogram_data(
#   File "c:\Users\victo\Desktop\MasterTrabajos\13MBID\13MBID\.venv\lib\site-packages\dtale\column_analysis.py", line 161, in build_histogram_data
#     hist_data, hist_labels = np.histogram(series, **hist_kwargs)
#   File "c:\Users\victo\Desktop\MasterTrabajos\13MBID\13MBID\.venv\lib\site-packages\numpy\lib\histograms.py", line 780, in histogram
#     bin_edges, uniform_bins = _get_bin_edges(a, bins, range, weights)
#   File "c:\Users\victo\Desktop\MasterTrabajos\13MBID\13MBID\.venv\lib\site-packages\numpy\lib\histograms.py", line 426, in _get_bin_edges
#     first_edge, last_edge = _get_outer_edges(a, range)
#   File "c:\Users\victo\Desktop\MasterTrabajos\13MBID\13MBID\.venv\lib\site-packages\numpy\lib\histograms.py", line 322, in _get_outer_edges
#     if not (np.isfinite(first_edge) and np.isfinite(last_edge)):
# TypeError: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
# Dataset: datos_tarjetas

tarjetas = dt.show(df_tarjetas)
tarjetas.open_browser()
# Out:
# 2024-04-20 18:05:33,294 - ERROR    - Exception occurred while processing request: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# Traceback (most recent call last):
#   File "c:\Users\victo\Desktop\MasterTrabajos\13MBID\13MBID\.venv\lib\site-packages\dtale\views.py", line 119, in _handle_exceptions
#     return func(*args, **kwargs)
#   File "c:\Users\victo\Desktop\MasterTrabajos\13MBID\13MBID\.venv\lib\site-packages\dtale\views.py", line 3135, in get_column_analysis
#     return jsonify(**analysis.build())
#   File "c:\Users\victo\Desktop\MasterTrabajos\13MBID\13MBID\.venv\lib\site-packages\dtale\column_analysis.py", line 141, in build
#     return_data, code = self.analysis.build(self)
#   File "c:\Users\victo\Desktop\MasterTrabajos\13MBID\13MBID\.venv\lib\site-packages\dtale\column_analysis.py", line 185, in build
#     return_data, hist_labels = self.build_histogram_data(
#   File "c:\Users\victo\Desktop\MasterTrabajos\13MBID\13MBID\.venv\lib\site-packages\dtale\column_analysis.py", line 161, in build_histogram_data
#     hist_data, hist_labels = np.histogram(series, **hist_kwargs)
#   File "c:\Users\victo\Desktop\MasterTrabajos\13MBID\13MBID\.venv\lib\site-packages\numpy\lib\histograms.py", line 780, in histogram
#     bin_edges, uniform_bins = _get_bin_edges(a, bins, range, weights)
#   File "c:\Users\victo\Desktop\MasterTrabajos\13MBID\13MBID\.venv\lib\site-packages\numpy\lib\histograms.py", line 426, in _get_bin_edges
#     first_edge, last_edge = _get_outer_edges(a, range)
#   File "c:\Users\victo\Desktop\MasterTrabajos\13MBID\13MBID\.venv\lib\site-packages\numpy\lib\histograms.py", line 322, in _get_outer_edges
#     if not (np.isfinite(first_edge) and np.isfinite(last_edge)):
# TypeError: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 2024-04-20 18:09:23,119 - ERROR    - Exception occurred while processing request: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# Traceback (most recent call last):
#   File "c:\Users\victo\Desktop\MasterTrabajos\13MBID\13MBID\.venv\lib\site-packages\dtale\views.py", line 119, in _handle_exceptions
#     return func(*args, **kwargs)
#   File "c:\Users\victo\Desktop\MasterTrabajos\13MBID\13MBID\.venv\lib\site-packages\dtale\views.py", line 3135, in get_column_analysis
#     return jsonify(**analysis.build())
#   File "c:\Users\victo\Desktop\MasterTrabajos\13MBID\13MBID\.venv\lib\site-packages\dtale\column_analysis.py", line 141, in build
#     return_data, code = self.analysis.build(self)
#   File "c:\Users\victo\Desktop\MasterTrabajos\13MBID\13MBID\.venv\lib\site-packages\dtale\column_analysis.py", line 185, in build
#     return_data, hist_labels = self.build_histogram_data(
#   File "c:\Users\victo\Desktop\MasterTrabajos\13MBID\13MBID\.venv\lib\site-packages\dtale\column_analysis.py", line 161, in build_histogram_data
#     hist_data, hist_labels = np.histogram(series, **hist_kwargs)
#   File "c:\Users\victo\Desktop\MasterTrabajos\13MBID\13MBID\.venv\lib\site-packages\numpy\lib\histograms.py", line 780, in histogram
#     bin_edges, uniform_bins = _get_bin_edges(a, bins, range, weights)
#   File "c:\Users\victo\Desktop\MasterTrabajos\13MBID\13MBID\.venv\lib\site-packages\numpy\lib\histograms.py", line 426, in _get_bin_edges
#     first_edge, last_edge = _get_outer_edges(a, range)
#   File "c:\Users\victo\Desktop\MasterTrabajos\13MBID\13MBID\.venv\lib\site-packages\numpy\lib\histograms.py", line 322, in _get_outer_edges
#     if not (np.isfinite(first_edge) and np.isfinite(last_edge)):
# TypeError: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 2024-04-20 18:12:13,362 - ERROR    - Exception occurred while processing request: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# Traceback (most recent call last):
#   File "c:\Users\victo\Desktop\MasterTrabajos\13MBID\13MBID\.venv\lib\site-packages\dtale\views.py", line 119, in _handle_exceptions
#     return func(*args, **kwargs)
#   File "c:\Users\victo\Desktop\MasterTrabajos\13MBID\13MBID\.venv\lib\site-packages\dtale\views.py", line 3135, in get_column_analysis
#     return jsonify(**analysis.build())
#   File "c:\Users\victo\Desktop\MasterTrabajos\13MBID\13MBID\.venv\lib\site-packages\dtale\column_analysis.py", line 141, in build
#     return_data, code = self.analysis.build(self)
#   File "c:\Users\victo\Desktop\MasterTrabajos\13MBID\13MBID\.venv\lib\site-packages\dtale\column_analysis.py", line 185, in build
#     return_data, hist_labels = self.build_histogram_data(
#   File "c:\Users\victo\Desktop\MasterTrabajos\13MBID\13MBID\.venv\lib\site-packages\dtale\column_analysis.py", line 161, in build_histogram_data
#     hist_data, hist_labels = np.histogram(series, **hist_kwargs)
#   File "c:\Users\victo\Desktop\MasterTrabajos\13MBID\13MBID\.venv\lib\site-packages\numpy\lib\histograms.py", line 780, in histogram
#     bin_edges, uniform_bins = _get_bin_edges(a, bins, range, weights)
#   File "c:\Users\victo\Desktop\MasterTrabajos\13MBID\13MBID\.venv\lib\site-packages\numpy\lib\histograms.py", line 426, in _get_bin_edges
#     first_edge, last_edge = _get_outer_edges(a, range)
#   File "c:\Users\victo\Desktop\MasterTrabajos\13MBID\13MBID\.venv\lib\site-packages\numpy\lib\histograms.py", line 322, in _get_outer_edges
#     if not (np.isfinite(first_edge) and np.isfinite(last_edge)):
# TypeError: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %% [markdown]
# ----
#
# ##### Gráficos de interés

# %%
plt.figure(figsize=(7,5))
sns.countplot(y=df_creditos['objetivo_credito'], order=df_creditos['objetivo_credito'].value_counts().index)
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.countplot(y=df_tarjetas['nivel_educativo'], order=df_tarjetas['nivel_educativo'].value_counts().index)
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.countplot(y=df_tarjetas['nivel_tarjeta'], order=df_tarjetas['nivel_tarjeta'].value_counts().index)
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.countplot(y=df_tarjetas['estado_civil'], order=df_tarjetas['estado_civil'].value_counts().index)
plt.show()

# %%
df_creditos.boxplot(column=['edad'])
# Out:
# <Axes: >

# %%
# In this heatmap, I am searching for missing values through the character ' '
cols = df_creditos.columns
colours = ['#000099', '#ffff00'] # specify the colours - yellow is missing. blue is not missing.
sns.heatmap(df_creditos[cols].isnull(), cmap=sns.color_palette(colours))
# Out:
# <Axes: >

# %%
# In this heatmap, I am searching for missing values through the character ' '
cols = df_tarjetas.columns
colours = ['#000099', '#ffff00'] # specify the colours - yellow is missing. blue is not missing.
sns.heatmap(df_tarjetas[cols].isnull(), cmap=sns.color_palette(colours))
# Out:
# <Axes: >
